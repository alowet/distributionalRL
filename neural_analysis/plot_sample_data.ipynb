# %%
import sys, os
from plotTrialAvgsByNeuron import plotTrialAvgsByNeuron
sys.path.append('../spikes')
from plot_spikes import plot_spikes
sys.path.append('../utils')
from db import get_db_info
# Out:
# Warning: cellpose did not import
# No module named 'cellpose'
# cannot use anatomical mode, but otherwise suite2p will run normally

# %%
paths = get_db_info()

# %% [markdown]
# ## Fig. 1h

# %%
name = 'AL39'
file_date_id = '20210930'
data_path = os.path.join(paths['ephys_root'], name, file_date_id)

# %%
plot_spikes(data_path, plot=1, rerun=0, plot_unexpected=1, highlights=[34, 43])
# Out:
# AL39 20210930 20210930
# ../../data/behavior/AL39/SameRewDist/Session Data 20210930 1900-01-01 11:17:31 ephys
# ['AL39_SameRewDist_20210930_111035.mat']
# 1
# inside
# /n/holystore01/LABS/uchida_users/Users/alowet/behavior/AL39/SameRewDist/Session Data/AL39_SameRewDist_20210930_111035.mat
# Already found classification for name = AL39, file_date_id = 20210930. Skipping
# 0        0
# 2        2
# 3        3
# 5        5
# 6        6
#       ...
# 211    282
# 212    283
# 214    285
# 215    286
# 216    289
# Name: cluster_id, Length: 76, dtype: int64
# 76
# Analyzing cell 0
# Analyzing cell 1
# Analyzing cell 2
# Analyzing cell 3
# Analyzing cell 4
# Analyzing cell 5
# Analyzing cell 6
# Analyzing cell 7
# Analyzing cell 8
# Analyzing cell 9
# Analyzing cell 10
# Analyzing cell 11
# Analyzing cell 12
# Analyzing cell 13
# Analyzing cell 14
# Analyzing cell 15
# Analyzing cell 16
# Analyzing cell 17
# Analyzing cell 18
# Analyzing cell 19
# Analyzing cell 20
# Analyzing cell 21
# Analyzing cell 22
# Analyzing cell 23
# Analyzing cell 24
# Analyzing cell 25
# Analyzing cell 26
# Analyzing cell 27
# Analyzing cell 28
# Analyzing cell 29
# Analyzing cell 30
# Analyzing cell 31
# Analyzing cell 32
# Analyzing cell 33
# Analyzing cell 34
# Analyzing cell 35
# Analyzing cell 36
# Analyzing cell 37
# Analyzing cell 38
# Analyzing cell 39
# Analyzing cell 40
# Analyzing cell 41
# Analyzing cell 42
# Analyzing cell 43
# Analyzing cell 44
# Analyzing cell 45
# Analyzing cell 46
# Analyzing cell 47
# Analyzing cell 48
# Analyzing cell 49
# Analyzing cell 50
# Analyzing cell 51
# Analyzing cell 52
# Analyzing cell 53
# Analyzing cell 54
# Analyzing cell 55
# Analyzing cell 56
# Analyzing cell 57
# Analyzing cell 58
# Analyzing cell 59
# Analyzing cell 60
# Analyzing cell 61
# Analyzing cell 62
# Analyzing cell 63
# Analyzing cell 64
# Analyzing cell 65
# Analyzing cell 66
# Analyzing cell 67
# Analyzing cell 68
# Analyzing cell 69
# Analyzing cell 70
# Analyzing cell 71
# Analyzing cell 72
# Analyzing cell 73
# Analyzing cell 74
# Analyzing cell 75
# meta NOT subset; don't know how to subset; dropped

# %% [markdown]
# ## Fig. 4d, g (plotted on separate axes for each trial type)

# %%
names = ['AL65', 'AL65', 'AL60']
file_date_ids = ['20220601', '20220531', '20220516']
cell_lsts = [[3], [4], [27, 32]]

# %%
for name, fid, cell_lst in zip(names, file_date_ids, cell_lsts):
    data_path = os.path.join(paths['imaging_root'], name, fid)
    plotTrialAvgsByNeuron(data_path, highlights=cell_lst)
# Out:
# AL65 20220601 20220601
# ../../data/behavior/AL65/SameRewDist/Session Data 20220601 1900-01-01 15:35:00 imaging
# ['AL65_SameRewDist_20220601_152743.mat']
# 1
# inside
# /n/holystore01/LABS/uchida_users/Users/alowet/behavior/AL65/SameRewDist/Session Data/AL65_SameRewDist_20220601_152743.mat
# Getting timestamps for mouse AL65, day 20220601
# 2
# Plotting deconv for channel Ca, mouse AL65, day 20220601
# AL65 20220601 0 / 35
# AL65 20220601 1 / 35
# AL65 20220601 2 / 35
# AL65 20220601 3 / 35
# AL65 20220601 4 / 35
# AL65 20220601 5 / 35
# AL65 20220601 6 / 35
# AL65 20220601 7 / 35
# AL65 20220601 8 / 35
# AL65 20220601 9 / 35
# AL65 20220601 10 / 35
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-5a8b66fb072a> in <module>
#       1 for name, fid, cell_lst in zip(names, file_date_ids, cell_lsts):
#       2     data_path = os.path.join(paths['imaging_root'], name, fid)
# ----> 3     plotTrialAvgsByNeuron(data_path, highlights=cell_lst)
#
# ~/Documents/dist-rl/to_publish/code/neural_analysis/plotTrialAvgsByNeuron.py in plotTrialAvgsByNeuron(video_dir, plot, highlights)
#     334                             pc = PatchCollection(rewrects, facecolors=reward_colors)
#     335                             ax.add_collection(pc)
# --> 336                             cax = raster_fig.add_axes([1.25, 0.65, .02, .2])
#     337                             cbar = raster_fig.colorbar(mpl.cm.ScalarMappable(norm=reward_norm, cmap=reward_cmap), cax=cax, ticks=[0, 2, 4, 6])
#     338                             cbar.set_label('Reward size ($\mu$L)', rotation=270, labelpad=15)
#
# ~/anaconda3/envs/neural/lib/python3.8/site-packages/matplotlib/figure.py in add_axes(self, *args, **kwargs)
#     640
#     641             # create the new axes using the axes class given
# --> 642             a = projection_class(self, rect, **pkw)
#     643             key = (projection_class, pkw)
#     644         return self._add_axes_internal(a, key)
#
# ~/anaconda3/envs/neural/lib/python3.8/site-packages/matplotlib/_api/deprecation.py in wrapper(*args, **kwargs)
#     454                 "parameter will become keyword-only %(removal)s.",
#     455                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 456         return func(*args, **kwargs)
#     457
#     458     # Don't modify *func*'s signature, as boilerplate.py needs it.
#
# ~/anaconda3/envs/neural/lib/python3.8/site-packages/matplotlib/axes/_base.py in __init__(self, fig, rect, facecolor, frameon, sharex, sharey, label, xscale, yscale, box_aspect, **kwargs)
#     630
#     631         self._rasterization_zorder = None
# --> 632         self.cla()
#     633
#     634         # funcs used to format x and y - fall back on major formatters
#
# ~/anaconda3/envs/neural/lib/python3.8/site-packages/matplotlib/axes/_base.py in cla(self)
#    1247         self.containers = []
#    1248
# -> 1249         self.grid(False)  # Disable grid on init to use rcParameter
#    1250         self.grid(self._gridOn, which=mpl.rcParams['axes.grid.which'],
#    1251                   axis=mpl.rcParams['axes.grid.axis'])
#
# ~/anaconda3/envs/neural/lib/python3.8/site-packages/matplotlib/_api/deprecation.py in wrapper(*args, **kwargs)
#     297                 f"for the old name will be dropped %(removal)s.")
#     298             kwargs[new] = kwargs.pop(old)
# --> 299         return func(*args, **kwargs)
#     300
#     301     # wrapper() must keep the same documented signature as func(): if we
#
# ~/anaconda3/envs/neural/lib/python3.8/site-packages/matplotlib/axes/_base.py in grid(self, visible, which, axis, **kwargs)
#    3226             self.xaxis.grid(visible, which=which, **kwargs)
#    3227         if axis in ['y', 'both']:
# -> 3228             self.yaxis.grid(visible, which=which, **kwargs)
#    3229
#    3230     def ticklabel_format(self, *, axis='both', style='', scilimits=None,
#
# ~/anaconda3/envs/neural/lib/python3.8/site-packages/matplotlib/_api/deprecation.py in wrapper(*args, **kwargs)
#     297                 f"for the old name will be dropped %(removal)s.")
#     298             kwargs[new] = kwargs.pop(old)
# --> 299         return func(*args, **kwargs)
#     300
#     301     # wrapper() must keep the same documented signature as func(): if we
#
# ~/anaconda3/envs/neural/lib/python3.8/site-packages/matplotlib/axis.py in grid(self, visible, which, **kwargs)
#    1432             gridkw['gridOn'] = (not self._major_tick_kw['gridOn']
#    1433                                 if visible is None else visible)
# -> 1434             self.set_tick_params(which='major', **gridkw)
#    1435         self.stale = True
#    1436
#
# ~/anaconda3/envs/neural/lib/python3.8/site-packages/matplotlib/axis.py in set_tick_params(self, which, reset, **kw)
#     871             if which in ['major', 'both']:
#     872                 self._major_tick_kw.update(kwtrans)
# --> 873                 for tick in self.majorTicks:
#     874                     tick._apply_params(**kwtrans)
#     875             if which in ['minor', 'both']:
#
# ~/anaconda3/envs/neural/lib/python3.8/site-packages/matplotlib/axis.py in __get__(self, instance, cls)
#     590             if self._major:
#     591                 instance.majorTicks = []
# --> 592                 tick = instance._get_tick(major=True)
#     593                 instance.majorTicks.append(tick)
#     594                 return instance.majorTicks
#
# ~/anaconda3/envs/neural/lib/python3.8/site-packages/matplotlib/axis.py in _get_tick(self, major)
#    2323         else:
#    2324             tick_kw = self._minor_tick_kw
# -> 2325         return YTick(self.axes, 0, major=major, **tick_kw)
#    2326
#    2327     def set_label_position(self, position):
#
# ~/anaconda3/envs/neural/lib/python3.8/site-packages/matplotlib/axis.py in __init__(self, *args, **kwargs)
#     489             verticalalignment=va, horizontalalignment=ha, transform=trans,
#     490         )
# --> 491         trans, va, ha = self._get_text2_transform()
#     492         self.label2.set(
#     493             x=1, y=0,
#
# ~/anaconda3/envs/neural/lib/python3.8/site-packages/matplotlib/axis.py in _get_text2_transform(self)
#     499
#     500     def _get_text2_transform(self):
# --> 501         return self.axes.get_yaxis_text2_transform(self._pad)
#     502
#     503     def _apply_tickdir(self, tickdir):
#
# ~/anaconda3/envs/neural/lib/python3.8/site-packages/matplotlib/axes/_base.py in get_yaxis_text2_transform(self, pad_points)
#     984         """
#     985         labels_align = mpl.rcParams["ytick.alignment"]
# --> 986         return (self.get_yaxis_transform(which='tick2') +
#     987                 mtransforms.ScaledTranslation(pad_points / 72, 0,
#     988                                               self.figure.dpi_scale_trans),
#
# ~/anaconda3/envs/neural/lib/python3.8/site-packages/matplotlib/transforms.py in __add__(self, other)
#    1353         ``C.transform(x) == B.transform(A.transform(x))``.
#    1354         """
# -> 1355         return (composite_transform_factory(self, other)
#    1356                 if isinstance(other, Transform) else
#    1357                 NotImplemented)
#
# ~/anaconda3/envs/neural/lib/python3.8/site-packages/matplotlib/transforms.py in composite_transform_factory(a, b)
#    2530     elif isinstance(a, Affine2D) and isinstance(b, Affine2D):
#    2531         return CompositeAffine2D(a, b)
# -> 2532     return CompositeGenericTransform(a, b)
#    2533
#    2534
#
# ~/anaconda3/envs/neural/lib/python3.8/site-packages/matplotlib/transforms.py in __init__(self, a, b, **kwargs)
#    2367         self._a = a
#    2368         self._b = b
# -> 2369         self.set_children(a, b)
#    2370
#    2371     def frozen(self):
#
# ~/anaconda3/envs/neural/lib/python3.8/site-packages/matplotlib/transforms.py in set_children(self, *children)
#     220             # performance improvement over using WeakValueDictionary.
#     221             ref = weakref.ref(
# --> 222                 self, lambda _, pop=child._parents.pop, k=id(self): pop(k))
#     223             child._parents[id(self)] = ref
#     224
#
# KeyboardInterrupt:

# %%
import sys, os
from plotTrialAvgsByNeuron import plotTrialAvgsByNeuron
sys.path.append('../spikes')
from plot_spikes import plot_spikes
sys.path.append('../utils')
from db import get_db_info
# Out:
# Warning: cellpose did not import
# No module named 'cellpose'
# cannot use anatomical mode, but otherwise suite2p will run normally

# %%
paths = get_db_info()

# %% [markdown]
# ## Fig. 1h

# %%
name = 'AL39'
file_date_id = '20210930'
data_path = os.path.join(paths['ephys_root'], name, file_date_id)

# %%
plot_spikes(data_path, plot=1, rerun=0, plot_unexpected=1, highlights=[34, 43])
# Out:
# AL39 20210930 20210930
# ../../data/behavior/AL39/SameRewDist/Session Data 20210930 1900-01-01 11:17:31 ephys
# ['AL39_SameRewDist_20210930_111035.mat']
# 1
# inside
# /n/holystore01/LABS/uchida_users/Users/alowet/behavior/AL39/SameRewDist/Session Data/AL39_SameRewDist_20210930_111035.mat
# Already found classification for name = AL39, file_date_id = 20210930. Skipping
# 0        0
# 2        2
# 3        3
# 5        5
# 6        6
#       ...
# 211    282
# 212    283
# 214    285
# 215    286
# 216    289
# Name: cluster_id, Length: 76, dtype: int64
# 76
# Analyzing cell 0
# Analyzing cell 1
# Analyzing cell 2
# Analyzing cell 3
# Analyzing cell 4
# Analyzing cell 5
# Analyzing cell 6
# Analyzing cell 7
# Analyzing cell 8
# Analyzing cell 9
# Analyzing cell 10
# Analyzing cell 11
# Analyzing cell 12
# Analyzing cell 13
# Analyzing cell 14
# Analyzing cell 15
# Analyzing cell 16
# Analyzing cell 17
# Analyzing cell 18
# Analyzing cell 19
# Analyzing cell 20
# Analyzing cell 21
# Analyzing cell 22
# Analyzing cell 23
# Analyzing cell 24
# Analyzing cell 25
# Analyzing cell 26
# Analyzing cell 27
# Analyzing cell 28
# Analyzing cell 29
# Analyzing cell 30
# Analyzing cell 31
# Analyzing cell 32
# Analyzing cell 33
# Analyzing cell 34
# Analyzing cell 35
# Analyzing cell 36
# Analyzing cell 37
# Analyzing cell 38
# Analyzing cell 39
# Analyzing cell 40
# Analyzing cell 41
# Analyzing cell 42
# Analyzing cell 43
# Analyzing cell 44
# Analyzing cell 45
# Analyzing cell 46
# Analyzing cell 47
# Analyzing cell 48
# Analyzing cell 49
# Analyzing cell 50
# Analyzing cell 51
# Analyzing cell 52
# Analyzing cell 53
# Analyzing cell 54
# Analyzing cell 55
# Analyzing cell 56
# Analyzing cell 57
# Analyzing cell 58
# Analyzing cell 59
# Analyzing cell 60
# Analyzing cell 61
# Analyzing cell 62
# Analyzing cell 63
# Analyzing cell 64
# Analyzing cell 65
# Analyzing cell 66
# Analyzing cell 67
# Analyzing cell 68
# Analyzing cell 69
# Analyzing cell 70
# Analyzing cell 71
# Analyzing cell 72
# Analyzing cell 73
# Analyzing cell 74
# Analyzing cell 75
# meta NOT subset; don't know how to subset; dropped

# %% [markdown]
# ## Fig. 4d, g

# %%
names = ['AL60', 'AL65', 'AL65']
file_date_ids = ['20220516', '20220601', '20220531']
cell_lsts = [[27, 32], [3], [4]]

# %%
for name, fid, cell_lst in zip(names, file_date_ids, cell_lsts):
    data_path = os.path.join(paths['imaging_root'], name, fid)
    plotTrialAvgsByNeuron(data_path, highlights=cell_lst)
# Out:
# AL60 20220516 20220516
# ../../data/behavior/AL60/SameRewDist/Session Data 20220516 1900-01-01 11:11:00 imaging
# ['AL60_SameRewDist_20220516_125258.mat', 'AL60_SameRewDist_20220516_105730.mat']
# 0
# 1
# inside
# /n/holystore01/LABS/uchida_users/Users/alowet/behavior/AL60/SameRewDist/Session Data/AL60_SameRewDist_20220516_105730.mat
# Getting timestamps for mouse AL60, day 20220516
# 2
# Plotting deconv for channel Ca, mouse AL60, day 20220516
# AL60 20220516 0 / 35
# AL60 20220516 1 / 35
# AL60 20220516 2 / 35
# AL60 20220516 3 / 35
# AL60 20220516 4 / 35
# AL60 20220516 5 / 35
